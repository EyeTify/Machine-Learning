# %%
#declare libraries
import os
import numpy as np
import cv2
import pandas as pd
import tensorflow as tf
import random

#untuk gambar dan plot
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix

#untuk esktraksi file
from zipfile import ZipFile

#untuk membangun model
from tensorflow.keras import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Dropout, Conv2D
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %% [markdown]
# **IMPORTING DATA AND EXTRACT ZIP FROM GOOGLE DRIVE**

# %%
#import dataset dari drive
from google.colab import drive
drive.mount('/content/drive')

local_zip = ZipFile("/content/drive/MyDrive/Eyetify.zip", 'r')
local_zip.extractall("/tmp/training")
local_zip.close()
# Out:
# Mounted at /content/drive

# %% [markdown]
# **IMAGE GENERATOR**

# %%
train_dir  = "/tmp/training/Eyetify"

def train_val_generators(TRAINING_DIR):
  train_datagen = ImageDataGenerator(rescale=1./255,
                                      horizontal_flip=False,
                                      shear_range=0.2,
                                      zoom_range=0.2,
                                      validation_split = 0.2,
                                      fill_mode='nearest')

  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      class_mode="categorical",
                                                      color_mode ="rgb",
                                                      batch_size=32,
                                                      subset = "training",
                                                       shuffle = True,
                                                      target_size=(160,160))


  # validation_datagen = ImageDataGenerator(rescale=1./255)
  validation_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                                class_mode="categorical",
                                                                color_mode ="rgb",
                                                                batch_size=32,
                                                                subset = "validation",
                                                                shuffle = False,
                                                                target_size=(160,160))

  return train_generator, validation_generator


train_generator, validation_generator = train_val_generators(train_dir)
train_generator.class_indices
# Out:
# Found 1249 images belonging to 8 classes.
# Found 310 images belonging to 8 classes.
# {'bulging': 0,
#  'cataract': 1,
#  'conjunctivitis': 2,
#  'crossed': 3,
#  'glaucoma': 4,
#  'hordeolum': 5,
#  'normal': 6,
#  'uveitis': 7}

# %% [markdown]
# **READING IMAGES**

# %%
images, labels = train_generator.next()
class_name = ['bulging', 'cataract','conjunctivitis', 'crossed', 'glaucoma','hordeolum','normal','uveitis']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    image = images[i]
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # plt.title(class_names[labels[i].argmax()])
    plt.imshow(image)
plt.show()

# %% [markdown]
# **BUILD THE MODEL**

# %%
# # #model using a inceptionV3
pretrained_model = InceptionV3(include_top=False, weights="imagenet", input_shape=(160,160,3))

x = pretrained_model.output
x = GlobalAveragePooling2D()(x)
# x = Flatten()(x)
x = BatchNormalization()(x)
x = Dropout(rate = 0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(rate = 0.7)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.5)(x)
pred = Dense(8, activation='softmax')(x)

model = Model(inputs=pretrained_model.input, outputs=pred)

for layer in pretrained_model.layers:
  layer.trainable = False

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 79, 79, 32)           864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 79, 79, 32)           96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 79, 79, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 77, 77, 32)           9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 77, 77, 32)           96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 77, 77, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 77, 77, 64)           18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 77, 77, 64)           192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 77, 77, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 38, 38, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 38, 38, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 38, 38, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 38, 38, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 36, 36, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 36, 36, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 36, 36, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 17, 17, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 17, 17, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 17, 17, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 17, 17, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 17, 17, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 17, 17, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 17, 17, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 17, 17, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 17, 17, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 17, 17, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 17, 17, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 17, 17, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 17, 17, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 17, 17, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 17, 17, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 17, 17, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 17, 17, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 17, 17, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 17, 17, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 17, 17, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 17, 17, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 17, 17, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 17, 17, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 17, 17, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 17, 17, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 17, 17, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 17, 17, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 17, 17, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 17, 17, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 17, 17, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 17, 17, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 17, 17, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 17, 17, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 17, 17, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 17, 17, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 17, 17, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 17, 17, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 17, 17, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 17, 17, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 17, 17, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 17, 17, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 17, 17, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 17, 17, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 17, 17, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 17, 17, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 17, 17, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 17, 17, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 96)             82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 8, 8, 384)            1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 8, 8, 96)             288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 384)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 8, 8, 96)             0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 288)            0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 8, 8, 768)            0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 8, 8, 128)            384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 8, 8, 128)            384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 8, 8, 128)            384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 8, 8, 128)            384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 8, 8, 128)            384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 8, 8, 128)            384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 8, 8, 768)            0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 8, 8, 192)            172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 192)            172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 192)            147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 8, 8, 192)            576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 8, 8, 192)            576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 8, 8, 192)            576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 8, 8, 192)            576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 8, 8, 768)            0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 8, 8, 160)            480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 8, 8, 160)            480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 160)            480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 8, 8, 160)            480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 8, 8, 160)            480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 8, 8, 160)            480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 8, 8, 768)            0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 192)            215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 8, 8, 192)            215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 8, 8, 192)            147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 192)            576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 8, 8, 192)            576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 8, 8, 192)            576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 8, 8, 192)            576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 8, 8, 768)            0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 8, 8, 160)            480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 8, 8, 160)            480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 8, 8, 160)            480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 8, 8, 160)            480       ['conv2d_56[0][0]']
#  tchNormalization)
# ...
#
#  conv2d_83 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 3, 3, 1280)           0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 3, 3, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 3, 3, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 3, 3, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 3, 3, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 3, 3, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 3, 3, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 3, 3, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 3, 3, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 3, 3, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 3, 3, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 3, 3, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 3, 3, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 3, 3, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 3, 3, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 3, 3, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 3, 3, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 3, 3, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 3, 3, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 3, 3, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 3, 3, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 3, 3, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 3, 3, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 3, 3, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 3, 3, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 3, 3, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 3, 3, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 3, 3, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 3, 3, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 3, 3, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 3, 3, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 3, 3, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 3, 3, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 3, 3, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 3, 3, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  batch_normalization_94 (Ba  (None, 2048)                 8192      ['global_average_pooling2d[0][
#  tchNormalization)                                                  0]']
#
#  dropout (Dropout)           (None, 2048)                 0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 1024)                 2098176   ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 8)                    8200      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23917352 (91.24 MB)
# Trainable params: 2110472 (8.05 MB)
# Non-trainable params: 21806880 (83.19 MB)
# __________________________________________________________________________________________________

# %%
model.compile(Adam(learning_rate= 0.0001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

initial_epoch = 40

history = model.fit(train_generator,
          epochs = initial_epoch,
          validation_data = validation_generator,
          steps_per_epoch = len(train_generator))
# Out:
# Epoch 1/40
# 40/40 [==============================] - 34s 485ms/step - loss: 2.7135 - accuracy: 0.4011 - val_loss: 1.3543 - val_accuracy: 0.5613
# Epoch 2/40
# 40/40 [==============================] - 14s 348ms/step - loss: 1.7084 - accuracy: 0.5693 - val_loss: 0.9433 - val_accuracy: 0.6677
# Epoch 3/40
# 40/40 [==============================] - 14s 350ms/step - loss: 1.4655 - accuracy: 0.6189 - val_loss: 0.8689 - val_accuracy: 0.7258
# Epoch 4/40
# 40/40 [==============================] - 16s 403ms/step - loss: 1.3160 - accuracy: 0.6509 - val_loss: 0.8144 - val_accuracy: 0.7516
# Epoch 5/40
# 40/40 [==============================] - 14s 343ms/step - loss: 1.1832 - accuracy: 0.6725 - val_loss: 0.7872 - val_accuracy: 0.7226
# Epoch 6/40
# 40/40 [==============================] - 14s 342ms/step - loss: 1.1252 - accuracy: 0.6829 - val_loss: 0.8016 - val_accuracy: 0.7516
# Epoch 7/40
# 40/40 [==============================] - 14s 340ms/step - loss: 1.0555 - accuracy: 0.6990 - val_loss: 0.7988 - val_accuracy: 0.7677
# Epoch 8/40
# 40/40 [==============================] - 14s 342ms/step - loss: 0.8923 - accuracy: 0.7382 - val_loss: 0.7887 - val_accuracy: 0.7516
# Epoch 9/40
# 40/40 [==============================] - 14s 344ms/step - loss: 0.9293 - accuracy: 0.7150 - val_loss: 0.7485 - val_accuracy: 0.7903
# Epoch 10/40
# 40/40 [==============================] - 13s 338ms/step - loss: 0.9596 - accuracy: 0.7294 - val_loss: 0.7700 - val_accuracy: 0.7871
# Epoch 11/40
# 40/40 [==============================] - 13s 339ms/step - loss: 0.8920 - accuracy: 0.7134 - val_loss: 0.8079 - val_accuracy: 0.7548
# Epoch 12/40
# 40/40 [==============================] - 14s 339ms/step - loss: 0.9363 - accuracy: 0.7358 - val_loss: 0.7752 - val_accuracy: 0.7935
# Epoch 13/40
# 40/40 [==============================] - 14s 339ms/step - loss: 0.7770 - accuracy: 0.7670 - val_loss: 0.7874 - val_accuracy: 0.7677
# Epoch 14/40
# 40/40 [==============================] - 13s 338ms/step - loss: 0.8736 - accuracy: 0.7302 - val_loss: 0.8347 - val_accuracy: 0.7677
# Epoch 15/40
# 40/40 [==============================] - 14s 343ms/step - loss: 0.7421 - accuracy: 0.7726 - val_loss: 0.7502 - val_accuracy: 0.7903
# Epoch 16/40
# 40/40 [==============================] - 14s 341ms/step - loss: 0.7632 - accuracy: 0.7574 - val_loss: 0.8046 - val_accuracy: 0.7839
# Epoch 17/40
# 40/40 [==============================] - 13s 336ms/step - loss: 0.7466 - accuracy: 0.7662 - val_loss: 0.7773 - val_accuracy: 0.7871
# Epoch 18/40
# 40/40 [==============================] - 14s 344ms/step - loss: 0.7062 - accuracy: 0.7670 - val_loss: 0.7510 - val_accuracy: 0.7806
# Epoch 19/40
# 40/40 [==============================] - 14s 346ms/step - loss: 0.6043 - accuracy: 0.7990 - val_loss: 0.6993 - val_accuracy: 0.8097
# Epoch 20/40
# 40/40 [==============================] - 14s 341ms/step - loss: 0.6625 - accuracy: 0.7686 - val_loss: 0.6847 - val_accuracy: 0.7871
# Epoch 21/40
# 40/40 [==============================] - 14s 342ms/step - loss: 0.6193 - accuracy: 0.8135 - val_loss: 0.6694 - val_accuracy: 0.7839
# Epoch 22/40
# 40/40 [==============================] - 14s 342ms/step - loss: 0.6516 - accuracy: 0.7798 - val_loss: 0.7303 - val_accuracy: 0.7839
# Epoch 23/40
# 40/40 [==============================] - 14s 342ms/step - loss: 0.6518 - accuracy: 0.7942 - val_loss: 0.7695 - val_accuracy: 0.7613
# Epoch 24/40
# 40/40 [==============================] - 13s 330ms/step - loss: 0.6036 - accuracy: 0.7910 - val_loss: 0.7293 - val_accuracy: 0.7645
# Epoch 25/40
# 40/40 [==============================] - 13s 338ms/step - loss: 0.6223 - accuracy: 0.7910 - val_loss: 0.6548 - val_accuracy: 0.8097
# Epoch 26/40
# 40/40 [==============================] - 13s 335ms/step - loss: 0.5678 - accuracy: 0.8078 - val_loss: 0.7102 - val_accuracy: 0.7871
# Epoch 27/40
# 40/40 [==============================] - 15s 360ms/step - loss: 0.6017 - accuracy: 0.7950 - val_loss: 0.6850 - val_accuracy: 0.8065
# Epoch 28/40
# 40/40 [==============================] - 13s 335ms/step - loss: 0.5648 - accuracy: 0.8151 - val_loss: 0.7930 - val_accuracy: 0.7774
# Epoch 29/40
# 40/40 [==============================] - 13s 332ms/step - loss: 0.5517 - accuracy: 0.8022 - val_loss: 0.6926 - val_accuracy: 0.7774
# Epoch 30/40
# 40/40 [==============================] - 13s 335ms/step - loss: 0.5350 - accuracy: 0.8327 - val_loss: 0.7108 - val_accuracy: 0.7903
# Epoch 31/40
# 40/40 [==============================] - 13s 338ms/step - loss: 0.5419 - accuracy: 0.8086 - val_loss: 0.7201 - val_accuracy: 0.7742
# Epoch 32/40
# 40/40 [==============================] - 13s 338ms/step - loss: 0.5124 - accuracy: 0.8215 - val_loss: 0.7445 - val_accuracy: 0.7968
# Epoch 33/40
# 40/40 [==============================] - 13s 332ms/step - loss: 0.5367 - accuracy: 0.8135 - val_loss: 0.7503 - val_accuracy: 0.7806
# Epoch 34/40
# 40/40 [==============================] - 13s 329ms/step - loss: 0.5206 - accuracy: 0.8151 - val_loss: 0.6861 - val_accuracy: 0.7839
# Epoch 35/40
# 40/40 [==============================] - 14s 343ms/step - loss: 0.4916 - accuracy: 0.8247 - val_loss: 0.6955 - val_accuracy: 0.7806
# Epoch 36/40
# 40/40 [==============================] - 14s 352ms/step - loss: 0.5109 - accuracy: 0.8295 - val_loss: 0.7265 - val_accuracy: 0.7968
# Epoch 37/40
# 40/40 [==============================] - 14s 339ms/step - loss: 0.5025 - accuracy: 0.8327 - val_loss: 0.6626 - val_accuracy: 0.8000
# Epoch 38/40
# 40/40 [==============================] - 13s 331ms/step - loss: 0.4603 - accuracy: 0.8327 - val_loss: 0.7440 - val_accuracy: 0.8032
# Epoch 39/40
# 40/40 [==============================] - 14s 341ms/step - loss: 0.4914 - accuracy: 0.8279 - val_loss: 0.7340 - val_accuracy: 0.7935
# Epoch 40/40
# 40/40 [==============================] - 14s 342ms/step - loss: 0.4563 - accuracy: 0.8407 - val_loss: 0.6576 - val_accuracy: 0.8194

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(acc, 'b', label='Training accuracy')
plt.plot(val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(loss, 'b', label='Training Loss')
plt.plot(val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
#fine tune
fine_tune = 100
# fine_tune = 50

for layer in pretrained_model.layers[:fine_tune]:
  layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['acc'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 79, 79, 32)           864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 79, 79, 32)           96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 79, 79, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 77, 77, 32)           9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 77, 77, 32)           96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 77, 77, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 77, 77, 64)           18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 77, 77, 64)           192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 77, 77, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 38, 38, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 38, 38, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 38, 38, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 38, 38, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 36, 36, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 36, 36, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 36, 36, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 17, 17, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 17, 17, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 17, 17, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 17, 17, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 17, 17, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 17, 17, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 17, 17, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 17, 17, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 17, 17, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 17, 17, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 17, 17, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 17, 17, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 17, 17, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 17, 17, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 17, 17, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 17, 17, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 17, 17, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 17, 17, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 17, 17, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 17, 17, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 17, 17, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 17, 17, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 17, 17, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 17, 17, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 17, 17, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 17, 17, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 17, 17, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 17, 17, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 17, 17, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 17, 17, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 17, 17, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 17, 17, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 17, 17, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 17, 17, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 17, 17, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 17, 17, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 17, 17, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 17, 17, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 17, 17, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 17, 17, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 17, 17, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 17, 17, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 17, 17, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 17, 17, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 17, 17, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 17, 17, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 17, 17, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 17, 17, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 17, 17, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 17, 17, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 17, 17, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 17, 17, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 17, 17, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 96)             82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 8, 8, 384)            1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 8, 8, 96)             288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 384)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 8, 8, 96)             0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 288)            0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 8, 8, 768)            0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 8, 8, 128)            384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 8, 8, 128)            384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 8, 8, 128)            384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 8, 8, 128)            384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 128)            114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 8, 8, 128)            384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 8, 8, 128)            384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 8, 8, 768)            0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 8, 8, 192)            172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 192)            172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 192)            147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 8, 8, 192)            576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 8, 8, 192)            576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 8, 8, 192)            576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 8, 8, 192)            576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 8, 8, 768)            0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 8, 8, 160)            480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 8, 8, 160)            480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 160)            480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 8, 8, 160)            480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 8, 8, 160)            480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 8, 8, 160)            480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 8, 8, 768)            0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 192)            215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 8, 8, 192)            215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 8, 8, 192)            147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 192)            576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 8, 8, 192)            576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 8, 8, 192)            576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 8, 8, 192)            576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 8, 8, 192)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 8, 8, 768)            0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 8, 8, 160)            480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 8, 8, 160)            480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 8, 8, 160)            179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 8, 8, 160)            480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 8, 8, 160)            480       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_51[0][0]
# ...
#
#  conv2d_83 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 3, 3, 1280)           0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 3, 3, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 3, 3, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 3, 3, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 3, 3, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 3, 3, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 3, 3, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 3, 3, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 3, 3, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 3, 3, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 3, 3, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 3, 3, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 3, 3, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 3, 3, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 3, 3, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 3, 3, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 3, 3, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 3, 3, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 3, 3, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 3, 3, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 3, 3, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 3, 3, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 3, 3, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 3, 3, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 3, 3, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 3, 3, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 3, 3, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 3, 3, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 3, 3, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 3, 3, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 3, 3, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 3, 3, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 3, 3, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 3, 3, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 3, 3, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 3, 3, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 3, 3, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  batch_normalization_94 (Ba  (None, 2048)                 8192      ['global_average_pooling2d[0][
#  tchNormalization)                                                  0]']
#
#  dropout (Dropout)           (None, 2048)                 0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 1024)                 2098176   ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 8)                    8200      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23917352 (91.24 MB)
# Trainable params: 2110472 (8.05 MB)
# Non-trainable params: 21806880 (83.19 MB)
# __________________________________________________________________________________________________

# %%
tuning_epoch = 20
total_epoch = initial_epoch + tuning_epoch

history_fine = model.fit(train_generator,
                     validation_data = validation_generator,
                     epochs = total_epoch,
                     initial_epoch = len(history.epoch))
# Out:
# Epoch 41/60
# 40/40 [==============================] - 23s 402ms/step - loss: 0.4435 - acc: 0.8431 - val_loss: 0.6885 - val_acc: 0.7903
# Epoch 42/60
# 40/40 [==============================] - 14s 341ms/step - loss: 0.4824 - acc: 0.8327 - val_loss: 0.6666 - val_acc: 0.8065
# Epoch 43/60
# 40/40 [==============================] - 13s 333ms/step - loss: 0.4674 - acc: 0.8319 - val_loss: 0.6782 - val_acc: 0.8065
# Epoch 44/60
# 40/40 [==============================] - 13s 329ms/step - loss: 0.4252 - acc: 0.8535 - val_loss: 0.7471 - val_acc: 0.7871
# Epoch 45/60
# 40/40 [==============================] - 13s 333ms/step - loss: 0.4704 - acc: 0.8391 - val_loss: 0.6907 - val_acc: 0.8065
# Epoch 46/60
# 40/40 [==============================] - 14s 343ms/step - loss: 0.4323 - acc: 0.8455 - val_loss: 0.6686 - val_acc: 0.8129
# Epoch 47/60
# 40/40 [==============================] - 14s 343ms/step - loss: 0.4162 - acc: 0.8639 - val_loss: 0.7382 - val_acc: 0.7903
# Epoch 48/60
# 40/40 [==============================] - 14s 340ms/step - loss: 0.4000 - acc: 0.8663 - val_loss: 0.7187 - val_acc: 0.8000
# Epoch 49/60
# 40/40 [==============================] - 14s 346ms/step - loss: 0.4429 - acc: 0.8527 - val_loss: 0.6719 - val_acc: 0.8065
# Epoch 50/60
# 40/40 [==============================] - 14s 339ms/step - loss: 0.4032 - acc: 0.8519 - val_loss: 0.7570 - val_acc: 0.7871
# Epoch 51/60
# 40/40 [==============================] - 14s 340ms/step - loss: 0.4209 - acc: 0.8535 - val_loss: 0.6913 - val_acc: 0.8032
# Epoch 52/60
# 40/40 [==============================] - 14s 342ms/step - loss: 0.4150 - acc: 0.8503 - val_loss: 0.7162 - val_acc: 0.7903
# Epoch 53/60
# 40/40 [==============================] - 13s 338ms/step - loss: 0.3957 - acc: 0.8599 - val_loss: 0.6979 - val_acc: 0.7968
# Epoch 54/60
# 40/40 [==============================] - 14s 344ms/step - loss: 0.3961 - acc: 0.8519 - val_loss: 0.7774 - val_acc: 0.8161
# Epoch 55/60
# 40/40 [==============================] - 15s 384ms/step - loss: 0.3632 - acc: 0.8671 - val_loss: 0.6388 - val_acc: 0.8129
# Epoch 56/60
# 40/40 [==============================] - 13s 338ms/step - loss: 0.3812 - acc: 0.8623 - val_loss: 0.7185 - val_acc: 0.7839
# Epoch 57/60
# 40/40 [==============================] - 13s 344ms/step - loss: 0.3578 - acc: 0.8759 - val_loss: 0.7170 - val_acc: 0.8194
# Epoch 58/60
# 40/40 [==============================] - 14s 341ms/step - loss: 0.3865 - acc: 0.8671 - val_loss: 0.7044 - val_acc: 0.7903
# Epoch 59/60
# 40/40 [==============================] - 13s 339ms/step - loss: 0.3739 - acc: 0.8663 - val_loss: 0.7394 - val_acc: 0.7839
# Epoch 60/60
# 40/40 [==============================] - 13s 339ms/step - loss: 0.3736 - acc: 0.8679 - val_loss: 0.6790 - val_acc: 0.8129

# %%
#plot training dan validation accuracy setelah fine tuning
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']
loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

plt.plot(acc, 'r', label='Training accuracy')
plt.plot([len(history.epoch), len(history.epoch)], plt.ylim(), label='Fine tune')
plt.plot(val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(loss, 'r', label='Training Loss')
plt.plot([len(history.epoch), len(history.epoch)], plt.ylim(), label='Fine tune')
plt.plot(val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# **TESTING**

# %%
y_testgen = validation_generator.classes
y_pred1 = model.predict(validation_generator)
y_pred1 = np.argmax(y_pred1, axis=1)

cm = confusion_matrix(y_testgen, y_pred1)
plot_confusion_matrix(conf_mat = cm,figsize=(8,8),class_names = ['blg', 'ctr','cjc', 'crs', 'glc','hrd','norm','uvt'],
                      show_normed = True);

cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['blg', 'ctr','cjc', 'crs', 'glc','hrd','norm','uvt'])
cm_display.plot()
plt.show()

accuracy= accuracy_score(validation_generator.classes, y_pred1)
precision = precision_score(validation_generator.classes, y_pred1, average=None)
recall= recall_score(validation_generator.classes, y_pred1, average=None)
f1 = f1_score(validation_generator.classes, y_pred1, average=None)
print(accuracy)
print(precision)
print(recall)
print(f1)
# Out:
# 10/10 [==============================] - 4s 243ms/step
# 0.7870967741935484
# [0.9047619  1.         0.6744186  0.90909091 0.81818182 0.6
#  0.48780488 0.5862069 ]
# [0.95       0.90677966 0.725      0.47619048 0.96428571 0.53571429
#  0.64516129 0.70833333]
# [0.92682927 0.95111111 0.69879518 0.625      0.8852459  0.56603774
#  0.55555556 0.64150943]

# %%
import random

class_names = ['blg', 'ctr','cjc', 'crs', 'glc','hrd','norm','uvt']
y_pred2 = model.predict(images)
plt.figure(figsize=(11, 7))

for i in range(25):
    sample_index = random.randint(0, images.shape[0] - 1)
    image = images[sample_index]

    label = class_names[labels[sample_index].argmax()]
    pred_label = class_names[y_pred2[sample_index].argmax()]

    plt.subplot(5, 5, i + 1)
    plt.imshow(image)
    plt.xlabel("Sebenarnya: {} \nPrediksi: {}".format(label, pred_label), fontsize=6)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# **DOWNLOAD MODEL**

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
# model.save("/content/drive/MyDrive/modeleyetify.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# #Convert to tflite
model.save("modeleyetify.h5")
model_eyetify = tf.keras.models.load_model("modeleyetify.h5")

# converter = tf.lite.TFLiteConverter.from_keras_model(model_eyetify)
# tflite_model = converter.convert()

# # Save the model.
# with open('modeleyetify.tflite', 'wb') as f:
#   f.write(tflite_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %%
# !sudo tensorflowjs_converter
# !tensorflowjs_converter --input_format=keras '/content/drive/MyDrive/modeleyetify.h5' "/content/drive/MyDrive/eyetifyjson"
# Out:
# 2024-06-09 17:57:45.809168: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-09 17:57:47.871288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorflowjs_converter", line 8, in <module>
#     sys.exit(pip_main())
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 959, in pip_main
#     main([' '.join(sys.argv[1:])])
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 963, in main
#     convert(argv[0].split(' '))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 894, in convert
#     raise ValueError(
# ValueError: Missing input_path argument. For usage, use the --help flag.
# 2024-06-09 17:57:51.795502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
